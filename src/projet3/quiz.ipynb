# %%
from palmerpenguins import load_penguins
data = load_penguins()

# %%
import pandas as pd

filename = "https://raw.githubusercontent.com/OpenClassrooms-Student-Center/8063076-Initiez-vous-au-Machine-Learning/master/data/palmer_penguins_openclassrooms.csv"
data = pd.read_csv(filename)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
X = data['bill_length_mm'].values.reshape(-1, 1)
y = data['body_mass_g']
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

filename = "https://raw.githubusercontent.com/OpenClassrooms-Student-Center/8063076-Initiez-vous-au-Machine-Learning/master/data/palmer_penguins_openclassrooms.csv"
data = pd.read_csv(filename)

features = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm"]
y = data["body_mass_g"]

for feature in features:
    X = data[[feature]]
    
    model = LinearRegression()
    model.fit(X, y)
    
    print(f"{feature} -> R² = {model.score(X, y):.4f}")
# Out:
# bill_length_mm -> R² = 0.3475
# bill_depth_mm -> R² = 0.2228
# flipper_length_mm -> R² = 0.7621

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Variables explicatives
X_raw = data[['bill_length_mm','bill_depth_mm','flipper_length_mm']]

# Target
y = data['body_mass_g']

# Scaling
scaler = MinMaxScaler()
X = scaler.fit_transform(X_raw)

# Modèle
reg = LinearRegression()
reg.fit(X, y)

# Prédictions
y_pred = reg.predict(X)

# RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))

# MAPE
mape = mean_absolute_percentage_error(y, y_pred)

print("RMSE:", rmse)
print("MAPE:", mape)
# Out:
# RMSE: 390.63708572458495
# MAPE: 0.07718264712272083

# %%
scaler = MinMaxScaler()
reg = LinearRegression()
for espece in ['Adelie', 'Gentoo', 'Chinstrap']:
    df = data[data.species == espece].copy()
    y = df['body_mass_g']
    X = scaler.fit_transform(df[['bill_length_mm','bill_depth_mm','flipper_length_mm']])
    reg.fit(X, y)
    print("--\n",espece, reg.score(X, y))

    y_pred = reg.predict(X)
    print(f"RMSE: {mean_squared_error(y, y_pred)}")
    print(f"MAPE: {mean_absolute_percentage_error(y, y_pred)}")
# Out:
# --
#  Adelie 0.5064249444393831
# RMSE: 103103.77927187757
# MAPE: 0.0688582880470465
# --
#  Gentoo 0.6280736371428207
# RMSE: 92745.4433440498
# MAPE: 0.047198617576817606
# --
#  Chinstrap 0.50381439825875
# RMSE: 72215.44695584575
# MAPE: 0.05660976676978927

# %%
scaler = MinMaxScaler()
y = data['body_mass_g']
X = scaler.fit_transform(data[['bill_length_mm','bill_depth_mm','flipper_length_mm']])
reg = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
score = []
test_size = 0.2

for random_state in np.arange(200):
      X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
      reg.fit(X_train, y_train)
      print("--\n",test_size, reg.score(X_test, y_test))
      score.append(reg.score(X_test, y_test))

import seaborn as sns
fig = plt.figure(figsize=(6, 6))
sns.boxplot(score)
plt.title(f"test_size {test_size}")
plt.show()
# Out:
# --
#  0.2 0.7902339700029893
# --
#  0.2 0.7655182716115203
# --
#  0.2 0.7196430740343781
# --
#  0.2 0.7495621198165492
# --
#  0.2 0.7336460599134988
# --
#  0.2 0.7961270129160324
# --
#  0.2 0.641856051244954
# --
#  0.2 0.755487990247808
# --
#  0.2 0.8133016703593214
# --
#  0.2 0.680483138540001
# --
#  0.2 0.6272687154145725
# --
#  0.2 0.7671131457743382
# --
#  0.2 0.7651203791761059
# --
#  0.2 0.7689337714118283
# --
#  0.2 0.7472117375564093
# --
#  0.2 0.7770840059170853
# --
#  0.2 0.7112216784059651
# --
#  0.2 0.7535978217996375
# --
#  0.2 0.7549153245750057
# --
#  0.2 0.7835078402357276
# --
#  0.2 0.7773655289841006
# --
#  0.2 0.8547883306701632
# --
#  0.2 0.7629439441283143
# --
#  0.2 0.7557028647461884
# --
#  0.2 0.7745166199989916
# --
#  0.2 0.7645430635648753
# --
#  0.2 0.8004084043810877
# --
#  0.2 0.8057543127709843
# --
#  0.2 0.7339493370553272
# --
#  0.2 0.7626023125658627
# --
#  0.2 0.7563330660213223
# --
#  0.2 0.7331120338034255
# --
#  0.2 0.7854995113971787
# --
#  0.2 0.8295802312169772
# --
#  0.2 0.7143824118134441
# --
#  0.2 0.7198518136469179
# --
#  0.2 0.7811629426622875
# --
#  0.2 0.7055264723468797
# --
#  0.2 0.7143039629365562
# --
#  0.2 0.7605016259993833
# --
#  0.2 0.7746706079265836
# --
#  0.2 0.6142162788265388
# --
#  0.2 0.732607331078129
# --
#  0.2 0.8298046414656947
# --
#  0.2 0.6744827052640032
# --
#  0.2 0.7586190259464833
# --
#  0.2 0.7558811403581198
# --
#  0.2 0.7594227835470334
# --
#  0.2 0.7924014828864641
# --
#  0.2 0.7864514347737634
# --
#  0.2 0.7329413113323546
# --
#  0.2 0.6403239122418429
# --
#  0.2 0.8301557322903581
# --
#  0.2 0.749054426981095
# --
#  0.2 0.7445616535282031
# --
#  0.2 0.7231654605971922
# --
#  0.2 0.7103549799070001
# --
#  0.2 0.7831514976688204
# --
#  0.2 0.8160802524325291
# --
#  0.2 0.6837322868894979
# --
#  0.2 0.7909823530811881
# --
#  0.2 0.7838744892709294
# --
#  0.2 0.8187906022446274
# --
#  0.2 0.6987309594806117
# --
#  0.2 0.7641248520683233
# --
#  0.2 0.7540184238597913
# --
#  0.2 0.688962689291247
# --
#  0.2 0.8103441129778729
# --
#  0.2 0.7905325713652751
# --
#  0.2 0.649439989059452
# --
#  0.2 0.7780587250296624
# --
#  0.2 0.7329769724144977
# --
#  0.2 0.7719785469731735
# --
#  0.2 0.7500335969588131
# --
#  0.2 0.7276300880173849
# --
#  0.2 0.7857460839976369
# --
#  0.2 0.715083242749031
# --
#  0.2 0.6823643387500825
# --
#  0.2 0.7886462436199083
# --
#  0.2 0.7236018849029462
# --
#  0.2 0.7514978798824531
# --
#  0.2 0.7801765763079456
# --
#  0.2 0.8076198377221314
# --
#  0.2 0.7685403603901643
# --
#  0.2 0.7632294318118196
# --
#  0.2 0.7471524067863993
# --
#  0.2 0.8331262961242776
# --
#  0.2 0.7462477506930683
# --
#  0.2 0.7677937385254039
# --
#  0.2 0.7222223046206635
# --
#  0.2 0.744101547800645
# --
#  0.2 0.7855510131815291
# --
#  0.2 0.7002463543915565
# --
#  0.2 0.7474230984797974
# --
#  0.2 0.7165967207730678
# --
#  0.2 0.7158332254279639
# --
#  0.2 0.8078410989822872
# --
#  0.2 0.6937445357445526
# --
#  0.2 0.7112420601238746
# --
#  0.2 0.7394517331525069
# --
#  0.2 0.7230721590661513
# --
#  0.2 0.7062339919965863
# --
#  0.2 0.7314460712411117
# --
#  0.2 0.8051478827122736
# --
#  0.2 0.7470285091081272
# --
#  0.2 0.7805796909661243
# --
#  0.2 0.7633814250590665
# --
#  0.2 0.8444012455150255
# --
#  0.2 0.7717157827490329
# --
#  0.2 0.7539318703109219
# --
#  0.2 0.8909539001117828
# --
#  0.2 0.7646294307692927
# --
#  0.2 0.7478138009529545
# --
#  0.2 0.7515921915144558
# --
#  0.2 0.8044937504457381
# --
#  0.2 0.7891085184027156
# --
#  0.2 0.7786760324096248
# --
#  0.2 0.8070896677948014
# --
#  0.2 0.7251482073444432
# --
#  0.2 0.7562288872864616
# --
#  0.2 0.7602504197596526
# --
#  0.2 0.764463016289587
# --
#  0.2 0.7654552673077646
# --
#  0.2 0.752794860584483
# --
#  0.2 0.759405460798984
# --
#  0.2 0.796698020604483
# --
#  0.2 0.8153286975359493
# --
#  0.2 0.7515139407176697
# --
#  0.2 0.8195713148616387
# --
#  0.2 0.8325824604686327
# --
#  0.2 0.819339291035749
# --
#  0.2 0.7461586870926038
# --
#  0.2 0.7480777186671367
# --
#  0.2 0.7788026459201363
# --
#  0.2 0.699124015416333
# --
#  0.2 0.7528268354413854
# --
#  0.2 0.6875171395210183
# --
#  0.2 0.7572752249831607
# --
#  0.2 0.7343410630260317
# --
#  0.2 0.7636362194691765
# --
#  0.2 0.7484982657124487
# --
#  0.2 0.8154966663953532
# --
#  0.2 0.754180934774107
# --
#  0.2 0.7624211122261135
# --
#  0.2 0.8143365830528263
# --
#  0.2 0.7983224862847283
# --
#  0.2 0.732893856732276
# --
#  0.2 0.7030908057390346
# --
#  0.2 0.7308348954119539
# --
#  0.2 0.7677898827254326
# --
#  0.2 0.7865848068169778
# --
#  0.2 0.7783340165982925
# --
#  0.2 0.7764688710103874
# --
#  0.2 0.8260353464431988
# --
#  0.2 0.7583202893413705
# --
#  0.2 0.7499841505101859
# --
#  0.2 0.7171101309813188
# --
#  0.2 0.7589302244882845
# --
#  0.2 0.8171455650551941
# --
#  0.2 0.7662468165780532
# --
#  0.2 0.7747773894211255
# --
#  0.2 0.7554000412750177
# --
#  0.2 0.7828099583189342
# --
#  0.2 0.7290774384437116
# --
#  0.2 0.7355541103496908
# --
#  0.2 0.7976693684671813
# --
#  0.2 0.7380447472737331
# --
#  0.2 0.7223396008037398
# --
#  0.2 0.7601037234557942
# --
#  0.2 0.6905859857362325
# --
#  0.2 0.720596223898336
# --
#  0.2 0.7849541703071801
# --
#  0.2 0.8157081274137286
# --
#  0.2 0.7080882487708353
# --
#  0.2 0.7462322645617759
# --
#  0.2 0.778722940972622
# --
#  0.2 0.7403127253729375
# --
#  0.2 0.6812866636539594
# --
#  0.2 0.7307118432082462
# --
#  0.2 0.7292659342558039
# --
#  0.2 0.7468163420312214
# --
#  0.2 0.8296937303850864
# --
#  0.2 0.8268643445312281
# --
#  0.2 0.6929798714871875
# --
#  0.2 0.7796657045754809
# --
#  0.2 0.7852921926308509
# --
#  0.2 0.7903800883366199
# --
#  0.2 0.7823423311261358
# --
#  0.2 0.6939816088570282
# --
#  0.2 0.7239519601141329
# --
#  0.2 0.6777722273947615
# --
#  0.2 0.7950267847911732
# --
#  0.2 0.7590759931235048
# --
#  0.2 0.7728308638104138
# --
#  0.2 0.6175247559994127
# --
#  0.2 0.7636973489250551
# --
#  0.2 0.6769018942078916
# --
#  0.2 0.823631275065388
# --
#  0.2 0.7834574468704619
# --
#  0.2 0.7573758663096624
